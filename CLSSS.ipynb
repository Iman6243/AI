# %% [markdown]
# <a href="https://colab.research.google.com/github/Iman6243/AI/blob/main/CLSSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy ,pandas, matplotlib

# %%
for i in range(1, 11):
    print(i)

# %%
i=1
while i<=10:
  print(i)
  i+=1

# %%
while True:
    user_input = input("لطفاً یک عدد وارد کنید: ")
    if user_input == "1370":
        print("عدد صحیح وارد شد. برنامه خاتمه یافت.")
        break
    else:
        print("عدد نادرست است. دوباره تلاش کنید.")

# %%
for i in range(2):
    user_input = input("لطفاً یک عدد وارد کنید: ")
    if user_input == "1370":
        print("عدد صحیح وارد شد. برنامه خاتمه یافت.")
        break
    else:
        print("عدد نادرست است. دوباره تلاش کنید.")

# %%
for x in range(11):
  for y in range(11):
   print(x, "x", y ,"=", x*y)

# %%
for i in range(2, 21, 2):
    print(i)

# %%
i = 2
while i <= 20:
    print(i)
    i += 2

# %%
for i in range(2, 21, 2):
    print(i)

# %%
for i in range(1,21):
  if i%2==0:
    print(i)

# %%
import matplotlib.pyplot as plt
import numpy as np

W=np.random.rand(20)
Y=np.random.rand(20,2)
X=np.random.rand(20,3)

u=[]
for i in range(1,21):
  u.append(i)

plt.plot(X)
plt.show()
